# %%
import pandas as pd
df = pd.read_csv('netflix_titles_nov_2019.csv')

# %%
df
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# 5833                   Joe Dante
# 5834                Ole Bornedal
# 5835                         NaN
# 5836        Sorin Dan Mihalcescu
#
#                                                    cast  \
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                     Christian Morales
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3     Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4     Abigail Oliver, Andrea Libman, Briana Buckmast...
# ...                                                 ...
# 5832  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...
# 5833  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...
# 5834  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...
# 5835                                                NaN
# 5836  Barbara King, Shaana Diya, John Krisiukenas, Y...
#
#                        country         date_added  release_year rating  \
# 0                  South Korea  November 30, 2019          2019  TV-14
# 1                          NaN  November 30, 2019          2019   TV-G
# 2                        India  November 30, 2019          2019  TV-14
# 3     France, Senegal, Belgium  November 29, 2019          2019  TV-14
# 4       Canada, United Kingdom                NaN          2019   TV-Y
# ...                        ...                ...           ...    ...
# 5832             United States   November 1, 2010          1987     NR
# 5833             United States  November 18, 2009          2009  TV-14
# 5834                   Denmark        May 5, 2009          2007     NR
# 5835             United States   February 4, 2008          2007  TV-MA
# 5836             United States    January 1, 2008          2006     NR
#
#        duration                                          listed_in  \
# 0      1 Season  International TV Shows, Korean TV Shows, Roman...
# 1        67 min                Documentaries, International Movies
# 2       135 min             Comedies, Dramas, International Movies
# 3       106 min   Dramas, Independent Movies, International Movies
# 4     2 Seasons                                           Kids' TV
# ...         ...                                                ...
# 5832     84 min                         Cult Movies, Horror Movies
# 5833     29 min                                      Horror Movies
# 5834    104 min                       Dramas, International Movies
# 5835   1 Season                       Stand-Up Comedy & Talk Shows
# 5836     81 min              Dramas, Independent Movies, Thrillers
#
#                                             description     type
# 0     Brought together by meaningful meals in the pa...  TV Show
# 1     From Sierra de las Minas to Esquipulas, explor...    Movie
# 2     A goofy copywriter unwittingly convinces the I...    Movie
# 3     Arranged to marry a rich man, young Ada is cru...    Movie
# 4     Lovable pug Chip starts kindergarten, makes ne...  TV Show
# ...                                                 ...      ...
# 5832  This collection cherry-picks trailers, forgott...    Movie
# 5833  After committing suicide, a washed-up rocker r...    Movie
# 5834  When he causes a car accident that leaves a yo...    Movie
# 5835  In each episode, four celebrities join host Jo...  TV Show
# 5836  While covering a story in New York City, a Sea...    Movie
#
# [5837 rows x 12 columns]

# %%
def create_textual_representation(row):
        textual_representation = f"""Type: {row['type']},
    Title: {row['title']},
    Director: {row['director']},
    Cast: {row['cast']},
    Released: {row['release_year']},
    Genres: {row['listed_in']},
    Description: {row['description']}"""
        return textual_representation

# %%
df['textual_representation'] = df.apply(create_textual_representation, axis=1)

# %%
df['textual_representation']
# Out:
# 0       Type: TV Show,\n    Title: Chocolate,\n    Dir...
# 1       Type: Movie,\n    Title: Guatemala: Heart of t...
# 2       Type: Movie,\n    Title: The Zoya Factor,\n   ...
# 3       Type: Movie,\n    Title: Atlantics,\n    Direc...
# 4       Type: TV Show,\n    Title: Chip and Potato,\n ...
#                               ...
# 5832    Type: Movie,\n    Title: Mad Ron's Prevues fro...
# 5833    Type: Movie,\n    Title: Splatter,\n    Direct...
# 5834    Type: Movie,\n    Title: Just Another Love Sto...
# 5835    Type: TV Show,\n    Title: Dinner for Five,\n ...
# 5836    Type: Movie,\n    Title: To and From New York,...
# Name: textual_representation, Length: 5837, dtype: object

# %%
print(df['textual_representation'].values[0])
# Out:
# Type: TV Show,
#     Title: Chocolate,
#     Director: nan,
#     Cast: Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang Bu-ja, Lee Jae-ryong, Min Jin-woong, Kim Won-hae, Yoo Teo,
#     Released: 2019,
#     Genres: International TV Shows, Korean TV Shows, Romantic TV Shows,
#     Description: Brought together by meaningful meals in the past and present, a doctor and a chef are reacquainted when they begin working at a hospice ward.

# %%
import faiss
import requests 
import numpy as np

dim = 4096

index = faiss.IndexFlatL2(dim)
x = np.zeros((len(df['textual_representation']), dim), dtype='float32')

# %%
index = faiss.read_index('index')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/hv/_fv6gtx16v10cc3ylvl4flqc0000gn/T/ipykernel_14352/3373682722.py in ?()
# ----> 1 index = faiss.read_index('index')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/faiss/swigfaiss.py in ?(*args)
#   10537 def read_index(*args):
# > 10538     return _swigfaiss.read_index(*args)
#
# RuntimeError: Error in faiss::FileIOReader::FileIOReader(const char *) at /Users/runner/work/faiss-wheels/faiss-wheels/faiss/faiss/impl/io.cpp:68: Error: 'f' failed: could not open index for reading: No such file or directory

# %%
df[df.title.str.contains('Shutter')]
# Out:
#        show_id    title                                  director  \
# 2805  70062814  Shutter  Banjong Pisanthanakun, Parkpoom Wongpoom
#
#                                                    cast   country  \
# 2805  Ananda Everingham, Natthaweeranuch Thongmee, A...  Thailand
#
#              date_added  release_year rating duration  \
# 2805  September 5, 2018          2004  TV-MA   96 min
#
#                                 listed_in  \
# 2805  Horror Movies, International Movies
#
#                                             description   type  \
# 2805  After killing a young girl in a hit-and-run ac...  Movie
#
#                                  textual_representation
# 2805  Type: Movie,\n    Title: Shutter,\n    Directo...
